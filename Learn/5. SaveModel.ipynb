# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('sample_data/teams.csv')

# %%
df
# Out:
#      team  year  athletes  events   age  height  weight  prev_medals  medals
# 0     AFG  1964         8       8  22.0   161.0    64.2          0.0       0
# 1     AFG  1968         5       5  23.2   170.2    70.0          0.0       0
# 2     AFG  1972         8       8  29.0   168.3    63.8          0.0       0
# 3     AFG  1980        11      11  23.6   168.4    63.2          0.0       0
# 4     AFG  2004         5       5  18.6   170.8    64.8          0.0       0
# ...   ...   ...       ...     ...   ...     ...     ...          ...     ...
# 2009  ZIM  2000        26      19  25.0   179.0    71.1          0.0       0
# 2010  ZIM  2004        14      11  25.1   177.8    70.5          0.0       3
# 2011  ZIM  2008        16      15  26.1   171.9    63.7          3.0       4
# 2012  ZIM  2012         9       8  27.3   174.4    65.2          4.0       0
# 2013  ZIM  2016        31      13  27.5   167.8    62.2          0.0       0
#
# [2014 rows x 9 columns]

# %% [markdown]
# #### Using SkLearn Library

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
x = df[['athletes', 'age', 'prev_medals']].copy()
y = df[['medals']].copy()

# %%
x
# Out:
#       athletes   age  prev_medals
# 0            8  22.0          0.0
# 1            5  23.2          0.0
# 2            8  29.0          0.0
# 3           11  23.6          0.0
# 4            5  18.6          0.0
# ...        ...   ...          ...
# 2009        26  25.0          0.0
# 2010        14  25.1          0.0
# 2011        16  26.1          3.0
# 2012         9  27.3          4.0
# 2013        31  27.5          0.0
#
# [2014 rows x 3 columns]

# %%
y
# Out:
#       medals
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 2009       0
# 2010       3
# 2011       4
# 2012       0
# 2013       0
#
# [2014 rows x 1 columns]

# %%
lr.fit(x, y)
# Out:
# LinearRegression()

# %%
print(lr.coef_)
print(lr.intercept_)
# Out:
# [[ 0.07117197 -0.11151931  0.7342536 ]]
# [0.7994324]

# %%
lr.predict([[21, 22, 2]])
# Out:
# c:\vsc\.vscode\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[1.30912619]])

# %% [markdown]
# #### Save Model

# %%
import pickle

# %% [markdown]
#     Dump model

# %%
with open('linreg_pickle','wb') as f:
    pickle.dump(lr,f)

# %% [markdown]
#     Load dumped model

# %%
with open('linreg_pickle','rb') as f:
    lp = pickle.load(f)

# %%
lp.coef_, lp.intercept_
# Out:
# (array([[ 0.07117197, -0.11151931,  0.7342536 ]]), array([0.7994324]))

# %% [markdown]
# #### Visualizing

# %%
import matplotlib.pyplot as plt

# %%
x.shape, y.shape
# Out:
# ((2014, 2), (2014, 1))

# %%
plt.scatter(x.athletes, y, marker='x')
plt.plot(x.athletes, predictions, 'r--')
plt.show()
