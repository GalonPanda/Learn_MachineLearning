# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('sample_data/carprices.csv')

# %%
df
# Out:
#     Mileage  Sell Price($)  Age(yrs)
# 0     69000          18000         6
# 1     35000          34000         3
# 2     57000          26100         5
# 3     22500          40000         2
# 4     46000          31500         4
# 5     59000          29400         5
# 6     52000          32000         5
# 7     72000          19300         6
# 8     91000          12000         8
# 9     67000          22000         6
# 10    83000          20000         7
# 11    79000          21000         7
# 12    59000          33000         5
# 13    48000          29500         4
# 14    52000          28000         4
# 15    61000          27500         5
# 16    43000          31000         4
# 17    68000          20000         6
# 18    77000          21000         7
# 19    33000          34500         3
# 20    92000          11000         8
# 21    85000          19000         7
# 22    44000          30500         4
# 23    36000          33500         3
# 24    25000          39000         2
# 25    58000          31500         5
# 26    71000          18500         6

# %%
plt.scatter(df['Age(yrs)'], df['Sell Price($)'])
plt.show()

# %%
x = df[['Mileage','Age(yrs)']]
y = df['Sell Price($)']

# %%
x.head()
# Out:
#    Mileage  Age(yrs)
# 0    69000         6
# 1    35000         3
# 2    57000         5
# 3    22500         2
# 4    46000         4

# %%
y.head()
# Out:
# 0    18000
# 1    34000
# 2    26100
# 3    40000
# 4    31500
# Name: Sell Price($), dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=.2,random_state=1)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
lr.predict(xtest)
# Out:
# array([22646.11236262, 29911.75506861, 18767.47900881, 40495.85978565,
#        35511.07242815, 17292.60700389])

# %%
lr.score(xtest,ytest)
# Out:
# 0.9212580070928141
